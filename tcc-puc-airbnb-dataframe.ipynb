# %%
import pandas as pd
import numpy as np

# %%
df_anuncios = pd.read_csv('anuncios.csv', index_col='id', engine='python', sep =',', encoding="utf-8")
df_anuncios.head()
# Out:
#          host_name host_response_time  host_response_rate host_is_superhost  \
# id
# 32046194     Allan     within an hour                 1.0                 f
# 2060895    Antonio     within an hour                 0.9                 f
# 8067388    Rafaela     within an hour                 1.0                 f
# 26081807   Claudia     within an hour                 1.0                 t
# 31051808   Mariana       within a day                 0.5                 f
#
#          host_identity_verified neighbourhood    zipcode  latitude  longitude  \
# id
# 32046194                      t       Ipanema   22410001 -22.98538  -43.19582
# 2060895                       f  Santa Teresa  20230-080 -22.91544  -43.18171
# 8067388                       f      Botafogo  22271-020 -22.95565  -43.19536
# 26081807                      t        Leblon  22440-035 -22.98617  -43.22759
# 31051808                      f      Botafogo  22260-120 -22.94991  -43.19289
#
#          property_type  ... review_scores_accuracy  review_scores_cleanliness  \
# id                      ...
# 32046194     Apartment  ...                    9.0                       10.0
# 2060895    Guest suite  ...                    9.0                        8.0
# 8067388      Apartment  ...                    7.0                        9.0
# 26081807     Apartment  ...                   10.0                       10.0
# 31051808     Apartment  ...                   10.0                        9.0
#
#           review_scores_checkin  review_scores_communication  \
# id
# 32046194                   10.0                         10.0
# 2060895                    10.0                         10.0
# 8067388                     9.0                          9.0
# 26081807                   10.0                         10.0
# 31051808                   10.0                          9.0
#
#           review_scores_location review_scores_value instant_bookable  \
# id
# 32046194                    10.0                 8.0                f
# 2060895                     10.0                 9.0                t
# 8067388                      8.0                 6.0                f
# 26081807                    10.0                10.0                f
# 31051808                     9.0                10.0                t
#
#                   cancellation_policy  calculated_host_listings_count  \
# id
# 32046194  strict_14_with_grace_period                               1
# 2060895                      moderate                               3
# 8067388   strict_14_with_grace_period                               1
# 26081807  strict_14_with_grace_period                               4
# 31051808                     moderate                               1
#
#           reviews_per_month
# id
# 32046194               0.40
# 2060895                0.70
# 8067388                0.04
# 26081807               3.92
# 31051808               0.18
#
# [5 rows x 36 columns]

# %%
df_amenities = pd.read_csv('amenities.csv', index_col='id', engine='python', sep =',', encoding="utf-8")
df_amenities.head()
# Out:
#           24-hour_check-in  Accessible-height_bed  Accessible-height_toilet  \
# id
# 32046194                 0                      0                         0
# 2060895                  0                      1                         1
# 8067388                  0                      0                         0
# 26081807                 0                      0                         0
# 31051808                 0                      0                         0
#
#           Air_conditioning  Amazon_Echo  BBQ_grill  Baby_bath  Baby_monitor  \
# id
# 32046194                 1            0          0          0             0
# 2060895                  0            0          0          0             0
# 8067388                  1            0          0          0             0
# 26081807                 1            0          0          0             0
# 31051808                 1            0          0          0             0
#
#           Babysitter_recommendations  Balcony  ...  Wide_entrance  \
# id                                             ...
# 32046194                           0        0  ...              0
# 2060895                            0        0  ...              1
# 8067388                            0        0  ...              0
# 26081807                           0        0  ...              0
# 31051808                           0        0  ...              0
#
#           Wide_entrance_for_guests  Wide_entryway  Wide_hallways  Wifi  \
# id
# 32046194                         0              0              0     1
# 2060895                          1              1              1     1
# 8067388                          0              0              0     1
# 26081807                         0              0              0     1
# 31051808                         0              0              0     1
#
#           Window_guards  Wine_cooler  _toilet  \
# id
# 32046194              0            0        0
# 2060895               1            0        1
# 8067388               0            0        0
# 26081807              0            0        0
# 31051808              0            0        0
#
#           translation_missing:_en.hosting_amenity_49  \
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
#
#           translation_missing:_en.hosting_amenity_50
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
#
# [5 rows x 167 columns]

# %%
df_metro_quadrado = pd.read_csv('metro_quadrado.csv', index_col='neighbourhood', engine='python', sep =',', encoding="utf-8")
df_metro_quadrado.head()
# Out:
#                   m2
# neighbourhood
# Ipanema        20907
# Copacabana     12170
# Leme           12210
# Catete         10487
# Lapa            3276

# %%
df_anuncios.describe()
# Out:
#        host_response_rate     latitude    longitude  accommodates  \
# count         9000.000000  9000.000000  9000.000000   9000.000000
# mean             0.916867   -22.970410   -43.230562      4.243222
# std              0.177116     0.028031     0.080161      2.348808
# min              0.000000   -23.072620   -43.567640      1.000000
# 25%              0.900000   -22.984620   -43.224972      2.000000
# 50%              1.000000   -22.975085   -43.192780      4.000000
# 75%              1.000000   -22.962750   -43.185115      5.000000
# max              1.000000   -22.806570   -43.159080     25.000000
#
#          bathrooms     bedrooms         beds         price  security_deposit  \
# count  9000.000000  9000.000000  9000.000000   9000.000000       9000.000000
# mean      1.600111     1.573000     2.646778    347.661889        645.295000
# std       0.888294     0.998612     1.986623    697.286816       1326.125618
# min       0.000000     0.000000     0.000000      0.000000          0.000000
# 25%       1.000000     1.000000     1.000000    139.000000          0.000000
# 50%       1.000000     1.000000     2.000000    210.000000        399.000000
# 75%       2.000000     2.000000     3.000000    361.000000        800.000000
# max      15.000000    15.000000    35.000000  31398.000000      20000.000000
#
#        cleaning_fee  ...  number_of_reviews  review_scores_rating  \
# count   9000.000000  ...        9000.000000           9000.000000
# mean     145.930667  ...          21.565333             94.822778
# std      102.716399  ...          34.932414              8.495257
# min        0.000000  ...           1.000000             20.000000
# 25%       90.000000  ...           3.000000             93.000000
# 50%      150.000000  ...           8.000000             98.000000
# 75%      190.000000  ...          24.000000            100.000000
# max     1469.000000  ...         372.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             9000.000000                9000.000000
# mean                 9.680000                   9.456556
# std                  0.799794                   0.983869
# min                  2.000000                   2.000000
# 25%                 10.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            9000.000000                  9000.000000
# mean                9.811778                     9.789111
# std                 0.660268                     0.681192
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             9000.000000          9000.000000
# mean                 9.801000             9.329889
# std                  0.613819             0.951167
# min                  2.000000             2.000000
# 25%                 10.000000             9.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                     9000.000000        9000.000000
# mean                         8.118889           0.860194
# std                         22.325101           0.974468
# min                          1.000000           0.010000
# 25%                          1.000000           0.180000
# 50%                          2.000000           0.530000
# 75%                          4.000000           1.160000
# max                        205.000000           8.410000
#
# [8 rows x 24 columns]

# %%
df_amenities.describe()
# Out:
#        24-hour_check-in  Accessible-height_bed  Accessible-height_toilet  \
# count       9000.000000            9000.000000               9000.000000
# mean           0.135333               0.103222                  0.078333
# std            0.342098               0.304266                  0.268710
# min            0.000000               0.000000                  0.000000
# 25%            0.000000               0.000000                  0.000000
# 50%            0.000000               0.000000                  0.000000
# 75%            0.000000               0.000000                  0.000000
# max            1.000000               1.000000                  1.000000
#
#        Air_conditioning  Amazon_Echo    BBQ_grill    Baby_bath  Baby_monitor  \
# count       9000.000000  9000.000000  9000.000000  9000.000000   9000.000000
# mean           0.863333     0.000111     0.054333     0.013333      0.001222
# std            0.343514     0.010541     0.226687     0.114704      0.034941
# min            0.000000     0.000000     0.000000     0.000000      0.000000
# 25%            1.000000     0.000000     0.000000     0.000000      0.000000
# 50%            1.000000     0.000000     0.000000     0.000000      0.000000
# 75%            1.000000     0.000000     0.000000     0.000000      0.000000
# max            1.000000     1.000000     1.000000     1.000000      1.000000
#
#        Babysitter_recommendations      Balcony  ...  Wide_entrance  \
# count                 9000.000000  9000.000000  ...    9000.000000
# mean                     0.018889     0.000444  ...       0.073222
# std                      0.136140     0.021078  ...       0.260515
# min                      0.000000     0.000000  ...       0.000000
# 25%                      0.000000     0.000000  ...       0.000000
# 50%                      0.000000     0.000000  ...       0.000000
# 75%                      0.000000     0.000000  ...       0.000000
# max                      1.000000     1.000000  ...       1.000000
#
#        Wide_entrance_for_guests  Wide_entryway  Wide_hallways       Wifi  \
# count               9000.000000    9000.000000    9000.000000  9000.0000
# mean                   0.134889       0.084000       0.125111     0.9400
# std                    0.341624       0.277403       0.330863     0.2375
# min                    0.000000       0.000000       0.000000     0.0000
# 25%                    0.000000       0.000000       0.000000     1.0000
# 50%                    0.000000       0.000000       0.000000     1.0000
# 75%                    0.000000       0.000000       0.000000     1.0000
# max                    1.000000       1.000000       1.000000     1.0000
#
#        Window_guards  Wine_cooler      _toilet  \
# count    9000.000000  9000.000000  9000.000000
# mean        0.057000     0.000444     0.029778
# std         0.231856     0.021078     0.169983
# min         0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000
# 50%         0.000000     0.000000     0.000000
# 75%         0.000000     0.000000     0.000000
# max         1.000000     1.000000     1.000000
#
#        translation_missing:_en.hosting_amenity_49  \
# count                                 9000.000000
# mean                                     0.094444
# std                                      0.292462
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        translation_missing:_en.hosting_amenity_50
# count                                 9000.000000
# mean                                     0.138000
# std                                      0.344919
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
# [8 rows x 167 columns]

# %%
df_metro_quadrado
# Out:
#                          m2
# neighbourhood
# Ipanema               20907
# Copacabana            12170
# Leme                  12210
# Catete                10487
# Lapa                   3276
# ...                     ...
# Vincente de Carvalho   1271
# Honório Gurgel         3064
# Cavalcante              980
# Deodoro                1000
# Complexo do Alemão      543
#
# [97 rows x 1 columns]

# %%
df_metro_quadrado.describe()
# Out:
#                  m2
# count     97.000000
# mean    3920.865979
# std     4671.820038
# min      440.000000
# 25%     1271.000000
# 50%     1689.000000
# 75%     4962.000000
# max    23626.000000

# %%
df_airbnb = pd.concat([df_anuncios, df_amenities], axis=1)
df_airbnb
# Out:
#                   host_name  host_response_time  host_response_rate  \
# id
# 32046194              Allan      within an hour                1.00
# 2060895             Antonio      within an hour                0.90
# 8067388             Rafaela      within an hour                1.00
# 26081807            Claudia      within an hour                1.00
# 31051808            Mariana        within a day                0.50
# ...                     ...                 ...                 ...
# 9585159              Nicole  a few days or more                0.25
# 33040588         Vera Lucia        within a day                0.83
# 316355    Paula And Marilia  within a few hours                0.91
# 20706150             Angela      within an hour                1.00
# 2081842           Elizabeth      within an hour                1.00
#
#          host_is_superhost host_identity_verified    neighbourhood    zipcode  \
# id
# 32046194                 f                      t          Ipanema   22410001
# 2060895                  f                      f     Santa Teresa  20230-080
# 8067388                  f                      f         Botafogo  22271-020
# 26081807                 t                      t           Leblon  22440-035
# 31051808                 f                      f         Botafogo  22260-120
# ...                    ...                    ...              ...        ...
# 9585159                  f                      t           Leblon  22430-210
# 33040588                 f                      f  Barra da Tijuca  22795-006
# 316355                   f                      f           Leblon  22431-000
# 20706150                 t                      f          Ipanema  22410-003
# 2081842                  f                      f       Copacabana  22051-002
#
#           latitude  longitude property_type  ... Wide_entrance  \
# id                                           ...
# 32046194 -22.98538  -43.19582     Apartment  ...             0
# 2060895  -22.91544  -43.18171   Guest suite  ...             1
# 8067388  -22.95565  -43.19536     Apartment  ...             0
# 26081807 -22.98617  -43.22759     Apartment  ...             0
# 31051808 -22.94991  -43.19289     Apartment  ...             0
# ...            ...        ...           ...  ...           ...
# 9585159  -22.98618  -43.22230     Apartment  ...             0
# 33040588 -23.01099  -43.37111     Apartment  ...             0
# 316355   -22.97916  -43.22686     Apartment  ...             0
# 20706150 -22.98422  -43.21260     Apartment  ...             0
# 2081842  -22.97370  -43.18741     Apartment  ...             0
#
#           Wide_entrance_for_guests  Wide_entryway  Wide_hallways  Wifi  \
# id
# 32046194                         0              0              0     1
# 2060895                          1              1              1     1
# 8067388                          0              0              0     1
# 26081807                         0              0              0     1
# 31051808                         0              0              0     1
# ...                            ...            ...            ...   ...
# 9585159                          0              0              0     1
# 33040588                         0              0              0     1
# 316355                           0              0              0     1
# 20706150                         0              0              0     1
# 2081842                          0              0              0     1
#
#          Window_guards Wine_cooler  _toilet  \
# id
# 32046194             0           0        0
# 2060895              1           0        1
# 8067388              0           0        0
# 26081807             0           0        0
# 31051808             0           0        0
# ...                ...         ...      ...
# 9585159              0           0        0
# 33040588             0           0        0
# 316355               0           0        0
# 20706150             0           0        0
# 2081842              0           0        0
#
#           translation_missing:_en.hosting_amenity_49  \
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
# ...                                              ...
# 9585159                                            0
# 33040588                                           0
# 316355                                             0
# 20706150                                           0
# 2081842                                            0
#
#           translation_missing:_en.hosting_amenity_50
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
# ...                                              ...
# 9585159                                            0
# 33040588                                           0
# 316355                                             0
# 20706150                                           0
# 2081842                                            0
#
# [9000 rows x 203 columns]

# %%
df_airbnb.drop(columns='amenities', inplace=True)
df_airbnb
# Out:
#                   host_name  host_response_time  host_response_rate  \
# id
# 32046194              Allan      within an hour                1.00
# 2060895             Antonio      within an hour                0.90
# 8067388             Rafaela      within an hour                1.00
# 26081807            Claudia      within an hour                1.00
# 31051808            Mariana        within a day                0.50
# ...                     ...                 ...                 ...
# 9585159              Nicole  a few days or more                0.25
# 33040588         Vera Lucia        within a day                0.83
# 316355    Paula And Marilia  within a few hours                0.91
# 20706150             Angela      within an hour                1.00
# 2081842           Elizabeth      within an hour                1.00
#
#          host_is_superhost host_identity_verified    neighbourhood    zipcode  \
# id
# 32046194                 f                      t          Ipanema   22410001
# 2060895                  f                      f     Santa Teresa  20230-080
# 8067388                  f                      f         Botafogo  22271-020
# 26081807                 t                      t           Leblon  22440-035
# 31051808                 f                      f         Botafogo  22260-120
# ...                    ...                    ...              ...        ...
# 9585159                  f                      t           Leblon  22430-210
# 33040588                 f                      f  Barra da Tijuca  22795-006
# 316355                   f                      f           Leblon  22431-000
# 20706150                 t                      f          Ipanema  22410-003
# 2081842                  f                      f       Copacabana  22051-002
#
#           latitude  longitude property_type  ... Wide_entrance  \
# id                                           ...
# 32046194 -22.98538  -43.19582     Apartment  ...             0
# 2060895  -22.91544  -43.18171   Guest suite  ...             1
# 8067388  -22.95565  -43.19536     Apartment  ...             0
# 26081807 -22.98617  -43.22759     Apartment  ...             0
# 31051808 -22.94991  -43.19289     Apartment  ...             0
# ...            ...        ...           ...  ...           ...
# 9585159  -22.98618  -43.22230     Apartment  ...             0
# 33040588 -23.01099  -43.37111     Apartment  ...             0
# 316355   -22.97916  -43.22686     Apartment  ...             0
# 20706150 -22.98422  -43.21260     Apartment  ...             0
# 2081842  -22.97370  -43.18741     Apartment  ...             0
#
#           Wide_entrance_for_guests  Wide_entryway  Wide_hallways  Wifi  \
# id
# 32046194                         0              0              0     1
# 2060895                          1              1              1     1
# 8067388                          0              0              0     1
# 26081807                         0              0              0     1
# 31051808                         0              0              0     1
# ...                            ...            ...            ...   ...
# 9585159                          0              0              0     1
# 33040588                         0              0              0     1
# 316355                           0              0              0     1
# 20706150                         0              0              0     1
# 2081842                          0              0              0     1
#
#          Window_guards  Wine_cooler  _toilet  \
# id
# 32046194             0            0        0
# 2060895              1            0        1
# 8067388              0            0        0
# 26081807             0            0        0
# 31051808             0            0        0
# ...                ...          ...      ...
# 9585159              0            0        0
# 33040588             0            0        0
# 316355               0            0        0
# 20706150             0            0        0
# 2081842              0            0        0
#
#           translation_missing:_en.hosting_amenity_49  \
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
# ...                                              ...
# 9585159                                            0
# 33040588                                           0
# 316355                                             0
# 20706150                                           0
# 2081842                                            0
#
#           translation_missing:_en.hosting_amenity_50
# id
# 32046194                                           0
# 2060895                                            0
# 8067388                                            0
# 26081807                                           0
# 31051808                                           0
# ...                                              ...
# 9585159                                            0
# 33040588                                           0
# 316355                                             0
# 20706150                                           0
# 2081842                                            0
#
# [9000 rows x 202 columns]

# %%
df_airbnb = df_airbnb.join(df_metro_quadrado, on='neighbourhood', how='left')

# %%
# Converte os atributos categóricos em quantitativos discretos.
for column in df_airbnb.columns:
    if str(df_airbnb[column].dtype) not in ['float64', 'int64']:
        df_airbnb[column] = df_airbnb[column].map \
        (dict(zip(df_airbnb[column].unique().tolist(),range(len(df_airbnb[column].unique().tolist())))))
df_airbnb
# Out:
#           host_name  host_response_time  host_response_rate  \
# id
# 32046194          0                   0                1.00
# 2060895           1                   0                0.90
# 8067388           2                   0                1.00
# 26081807          3                   0                1.00
# 31051808          4                   1                0.50
# ...             ...                 ...                 ...
# 9585159        2444                   3                0.25
# 33040588       1674                   1                0.83
# 316355         1026                   2                0.91
# 20706150        120                   0                1.00
# 2081842         904                   0                1.00
#
#           host_is_superhost  host_identity_verified  neighbourhood  zipcode  \
# id
# 32046194                  0                       0              0        0
# 2060895                   0                       1              1        1
# 8067388                   0                       1              2        2
# 26081807                  1                       0              3        3
# 31051808                  0                       1              2        4
# ...                     ...                     ...            ...      ...
# 9585159                   0                       0              3      187
# 33040588                  0                       1              6      468
# 316355                    0                       1              3      161
# 20706150                  1                       1              0       56
# 2081842                   0                       1              7       99
#
#           latitude  longitude  property_type  ...  Wide_entrance_for_guests  \
# id                                            ...
# 32046194 -22.98538  -43.19582              0  ...                         0
# 2060895  -22.91544  -43.18171              1  ...                         1
# 8067388  -22.95565  -43.19536              0  ...                         0
# 26081807 -22.98617  -43.22759              0  ...                         0
# 31051808 -22.94991  -43.19289              0  ...                         0
# ...            ...        ...            ...  ...                       ...
# 9585159  -22.98618  -43.22230              0  ...                         0
# 33040588 -23.01099  -43.37111              0  ...                         0
# 316355   -22.97916  -43.22686              0  ...                         0
# 20706150 -22.98422  -43.21260              0  ...                         0
# 2081842  -22.97370  -43.18741              0  ...                         0
#
#           Wide_entryway  Wide_hallways  Wifi  Window_guards  Wine_cooler  \
# id
# 32046194              0              0     1              0            0
# 2060895               1              1     1              1            0
# 8067388               0              0     1              0            0
# 26081807              0              0     1              0            0
# 31051808              0              0     1              0            0
# ...                 ...            ...   ...            ...          ...
# 9585159               0              0     1              0            0
# 33040588              0              0     1              0            0
# 316355                0              0     1              0            0
# 20706150              0              0     1              0            0
# 2081842               0              0     1              0            0
#
#           _toilet  translation_missing:_en.hosting_amenity_49  \
# id
# 32046194        0                                           0
# 2060895         1                                           0
# 8067388         0                                           0
# 26081807        0                                           0
# 31051808        0                                           0
# ...           ...                                         ...
# 9585159         0                                           0
# 33040588        0                                           0
# 316355          0                                           0
# 20706150        0                                           0
# 2081842         0                                           0
#
#           translation_missing:_en.hosting_amenity_50     m2
# id
# 32046194                                           0  20907
# 2060895                                            0   7868
# 8067388                                            0  11379
# 26081807                                           0  23626
# 31051808                                           0  11379
# ...                                              ...    ...
# 9585159                                            0  23626
# 33040588                                           0   9335
# 316355                                             0  23626
# 20706150                                           0  20907
# 2081842                                            0  12170
#
# [9000 rows x 203 columns]

# %%
# Lista de atributos com maior correlação direta ou inversa com o preço

corr = df_airbnb.corr()
corr['abs_price'] = abs(corr['price'])
corr.sort_values(by = ['abs_price'], ascending = False, inplace = True)
corr['price'][1:51]
# Out:
# bathrooms                         0.339702
# bedrooms                          0.332185
# cleaning_fee                      0.292823
# accommodates                      0.283016
# security_deposit                  0.228746
# beds                              0.227224
# guests_included                   0.206347
# Free_parking_on_premises          0.153615
# extra_people                      0.147303
# Pool                              0.137573
# Dryer                             0.127535
# m2                                0.103549
# latitude                         -0.103310
# reviews_per_month                -0.099972
# Hot_tub                           0.099358
# Air_conditioning                  0.093584
# Crib                              0.093541
# Washer                            0.092880
# Dishwasher                        0.086856
# Suitable_for_events               0.080509
# Family/kid_friendly               0.080476
# property_type                     0.080342
# Full_kitchen                      0.078409
# Internet                          0.078405
# Bathtub                           0.076397
# number_of_reviews                -0.074451
# calculated_host_listings_count    0.073399
# Cable_TV                          0.071183
# room_type                        -0.069641
# Wheelchair_accessible             0.068952
# Pack_’n_Play/travel_crib          0.067297
# Indoor_fireplace                  0.067285
# Dishes_and_silverware            -0.066192
# Paid_parking_off_premises        -0.065746
# Doorman                           0.065220
# Hot_water                        -0.065191
# High_chair                        0.062138
# Extra_pillows_and_blankets       -0.056673
# neighbourhood                    -0.055464
# BBQ_grill                         0.054995
# Hair_dryer                        0.054976
# Bed_linens                       -0.054297
# Stove                            -0.052263
# Private_pool                      0.051720
# Cooking_basics                   -0.049069
# Refrigerator                     -0.049040
# Buzzer/wireless_intercom          0.046848
# Beachfront                        0.045049
# Outdoor_seating                   0.044656
# instant_bookable                 -0.044161
# Name: price, dtype: float64

# %%
# Seleção dos vinte atributos mais relevantes à modelagem preditiva (feature selection).

# Atributos redundantes não serão selecionados para não confundir o modelo.
# A seleção será feita com base na força da correlação e na unicidade da característica descrita
# Por exemplo: Bathrooms, bedrooms, accomodates e beds referem-se à mesma característica: Capacidade de acomodação do imóvel
# Portanto, desses atributos, apenas um será selecionado.
# De acordo com o conhecimento do negócio, para essa característica, será Bedrooms.
# Pois o atributo de maior destaque em relação à acomodação, em anúncios de hospedagem, costuma ser a quantidade de quartos.

# Como o dataset possui 202 atributos e, pela descrição dos atributos mais relevantes, selecionamos os 10% melhores.

correlated = ['bedrooms', 'cleaning_fee', 'security_deposit', 'Free_parking_on_premises', 'extra_people', 'Pool', 'Dryer', 'm2', 'reviews_per_month', 'Hot_tub', 'Air_conditioning', 'Crib', 'Washer', 'Dishwasher', 'Suitable_for_events', 'property_type', 'Full_kitchen', 'Internet', 'Bathtub', 'Cable_TV']

# %%
# Seleção de atributos auxiliares e alvo

location = ['latitude', 'longitude', 'neighbourhood']
target = ['price']

# %%
# elaboração da lista de features a serem analisadas

features = location + correlated + target
features
# Out:
# ['latitude',
#  'longitude',
#  'neighbourhood',
#  'bedrooms',
#  'cleaning_fee',
#  'security_deposit',
#  'Free_parking_on_premises',
#  'extra_people',
#  'Pool',
#  'Dryer',
#  'm2',
#  'reviews_per_month',
#  'Hot_tub',
#  'Air_conditioning',
#  'Crib',
#  'Washer',
#  'Dishwasher',
#  'Suitable_for_events',
#  'property_type',
#  'Full_kitchen',
#  'Internet',
#  'Bathtub',
#  'Cable_TV',
#  'price']

# %%
df_airbnb = df_airbnb[features]
df_airbnb
# Out:
#           latitude  longitude  neighbourhood  bedrooms  cleaning_fee  \
# id
# 32046194 -22.98538  -43.19582              0       2.0          73.0
# 2060895  -22.91544  -43.18171              1       1.0          35.0
# 8067388  -22.95565  -43.19536              2       2.0         160.0
# 26081807 -22.98617  -43.22759              3       1.0         120.0
# 31051808 -22.94991  -43.19289              2       3.0         150.0
# ...            ...        ...            ...       ...           ...
# 9585159  -22.98618  -43.22230              3       3.0         400.0
# 33040588 -23.01099  -43.37111              6       1.0          90.0
# 316355   -22.97916  -43.22686              3       1.0         195.0
# 20706150 -22.98422  -43.21260              0       2.0         180.0
# 2081842  -22.97370  -43.18741              7       2.0         200.0
#
#           security_deposit  Free_parking_on_premises  extra_people  Pool  \
# id
# 32046194               0.0                         0          49.0     0
# 2060895                0.0                         0          25.0     0
# 8067388                0.0                         0          90.0     0
# 26081807            1200.0                         0         100.0     0
# 31051808               0.0                         0          70.0     0
# ...                    ...                       ...           ...   ...
# 9585159             2000.0                         0           0.0     0
# 33040588               0.0                         1           0.0     1
# 316355               825.0                         0          98.0     0
# 20706150               0.0                         0         100.0     0
# 2081842              500.0                         0           0.0     0
#
#           Dryer  ...  Crib  Washer  Dishwasher  Suitable_for_events  \
# id               ...
# 32046194      0  ...     0       0           0                    0
# 2060895       0  ...     0       1           0                    1
# 8067388       0  ...     0       1           0                    0
# 26081807      0  ...     0       0           0                    0
# 31051808      0  ...     0       1           0                    0
# ...         ...  ...   ...     ...         ...                  ...
# 9585159       1  ...     0       1           0                    0
# 33040588      0  ...     0       0           0                    0
# 316355        0  ...     0       0           0                    1
# 20706150      0  ...     0       1           0                    0
# 2081842       0  ...     0       1           0                    0
#
#           property_type  Full_kitchen  Internet  Bathtub  Cable_TV   price
# id
# 32046194              0             0         0        0         0   395.0
# 2060895               1             0         1        0         0    84.0
# 8067388               0             0         1        0         1   382.0
# 26081807              0             0         0        0         1   151.0
# 31051808              0             0         0        0         0   348.0
# ...                 ...           ...       ...      ...       ...     ...
# 9585159               0             0         1        0         1  2599.0
# 33040588              0             0         0        0         0   369.0
# 316355                0             0         1        0         1   181.0
# 20706150              0             0         0        0         1   260.0
# 2081842               0             0         1        0         1   252.0
#
# [9000 rows x 24 columns]

# %%
df_airbnb.to_csv('airbnb.csv')
